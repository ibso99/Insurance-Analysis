# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os, sys
current_dir = os.getcwd()
print(current_dir)

parent_dir = os.path.dirname(current_dir)
print(parent_dir)

sys.path.insert(0,parent_dir)
# Out:
# c:\Users\ibsan\Desktop\TenX\week-3\notebooks
# c:\Users\ibsan\Desktop\TenX\week-3

# %%
# from src.DataPipeline import DataPipeline
from src.InsuranceAnalyzer import InsuranceDataAnalyzer

# %%
data_path = "C:/Users/ibsan/Desktop/TenX/week-3/Data/MachineLearningRating_v3.csv"
Insurance_analyzer = InsuranceDataAnalyzer(data_path)
# Out:
# Data loaded and copied successfully.

# %%
Insurance_analyzer.data_quality_assessment()
# Out:
# Missing Values per Column:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# ...

# %%
cleaned_df = Insurance_analyzer.handle_missing_values()
print(cleaned_df.isnull().sum())
# Out:
# Handling missing values...
# Column Bank is not numeric, skipping imputation and conversion.
# Column AccountType is not numeric, skipping imputation and conversion.
# Column MaritalStatus is not numeric, skipping imputation and conversion.
# Column Gender is not numeric, skipping imputation and conversion.
# Error converting column 'mmcode' to numeric: Unable to parse string "nan" at position 487033
# Dropping column 'mmcode'
# Column VehicleType is not numeric, skipping imputation and conversion.
# Column make is not numeric, skipping imputation and conversion.
# Column Model is not numeric, skipping imputation and conversion.
# Error converting column 'Cylinders' to numeric: Unable to parse string "nan" at position 487033
# Dropping column 'Cylinders'
# Error converting column 'cubiccapacity' to numeric: Unable to parse string "nan" at position 487033
# Dropping column 'cubiccapacity'
# ...

# %%
Insurance_analyzer.data_summarization()
# Out:
# Descriptive Statistics for numerical features:
#        TotalPremium   TotalClaims  CalculatedPremiumPerTerm    SumInsured  \
# count  1.000098e+06  1.000098e+06              1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01              1.178757e+02  6.041727e+05
# std    2.302845e+02  2.384075e+03              3.997017e+02  1.508332e+06
# min   -7.825768e+02 -1.200241e+04              0.000000e+00  1.000000e-02
# 25%    0.000000e+00  0.000000e+00              3.224800e+00  5.000000e+03
# 50%    2.178333e+00  0.000000e+00              8.436900e+00  7.500000e+03
# 75%    2.192982e+01  0.000000e+00              9.000000e+01  2.500000e+05
# max    6.528260e+04  3.930921e+05              7.442217e+04  1.263620e+07
#
#        RegistrationYear
# count      1.000098e+06
# mean       2.010225e+03
# std        3.261391e+00
# min        1.987000e+03
# 25%        2.008000e+03
# 50%        2.011000e+03
# 75%        2.013000e+03
# max        2.015000e+03
#
# ...

# %%
Insurance_analyzer.univariate_analysis()

# %%
Insurance_analyzer.bivariate_analysis()
# Out:
# Analysing correlations between TotalPremium and TotalClaims with different features
# Error converting column 'CapitalOutstanding' to numeric in Bivariate analysis: Unable to parse string "nan" at position 47762
# Dropping column 'CapitalOutstanding' in Bivariate analysis

# %%
Insurance_analyzer.data_comparison()
# Out:
# Comparing trends based on  insurance cover type, premium and auto make..

# %%
Insurance_analyzer.outlier_detection()

# %%
Insurance_analyzer.visualization()
# Out:
# Generating a pairplot for selected numerical features..
# Generating distribution of premium and claim based on provinces
# Generating countplot of vehicle type by marital status..
